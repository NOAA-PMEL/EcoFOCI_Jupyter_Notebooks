# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_excel('/Users/bell/ecoraid/2018/Moorings/18ckip2a/rawconverted/rcm/18ckip2a_rcm858.xlsx',
                   skiprows=4,parse_dates=True,index_col='date/time')

# %%
df.temperature.plot()
