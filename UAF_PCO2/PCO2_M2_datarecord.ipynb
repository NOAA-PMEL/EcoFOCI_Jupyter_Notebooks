# %% [markdown]
# # Read PCO2 M2 data record

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/bell/in_and_outbox/Ongoing_Analysis/M2_PCO2/M2_pco2_all.csv',parse_dates=True, index_col='Date Time (UTC)')

# %%
pd.to_numeric(df[' Sea Surface Temperature (deg C)'],errors='coerce').plot(figsize=(12,2))
# Out:
# <AxesSubplot:xlabel='Date Time (UTC)'>

# %%
df.columns
# Out:
# Index([' Pressure (kPa)', ' xCO2 of Seawater (umol/mol)',
#        ' xCO2 of Air (umol/mol)', ' pH of Seawater (total scale)',
#        ' Sea Surface Salinity', ' Sea Surface Temperature (deg C)',
#        ' Chlorophyll (ug/l)', ' Turbidity (NTU)',
#        ' Salinity-Compensated O2 (uM)', ' Salinity-Compensated O2 (mg/l)',
#        ' Salinity-Compensated O2 (umol/kg)', ' sigma-theta (kg/m3)'],
#       dtype='object')
