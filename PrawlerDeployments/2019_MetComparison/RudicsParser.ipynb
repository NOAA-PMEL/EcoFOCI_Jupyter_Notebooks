# %%
fp = 'M2 MetPackage Test/CM002_02_04-03_08.txt'

eng = False
baro = False
wind = False
praw = False
gps = False
atrh = False

with open(fp) as f:
    for line in f:
        if ('%%BARO' in line) or wind:
            print(line)
            wind=True
            if any((True for x in ['%%eng','%%ATRH','%%WIND','%%praw','%%GPS'] if x in line)):
                wind=False
# Out:
# %%BARO
#
# DT,BP
#
# 2019-02-26T13:40:00Z,1017.82
#
# 2019-02-26T13:50:00Z,1017.87
#
# 2019-02-26T14:00:00Z,1017.96
#
# 2019-02-26T14:10:00Z,1018.01
#
# 2019-02-26T14:20:00Z,1018.06
#
# 2019-02-26T14:30:00Z,1018.20
#
# 2019-02-26T14:40:00Z,1018.33
#
# 2019-02-26T14:50:00Z,1018.50
#
# 2019-02-26T15:00:00Z,1018.68
#
# 2019-02-26T15:10:00Z,1018.82
#
# 2019-02-26T15:20:00Z,1018.98
#
# 2019-02-26T15:30:00Z,1019.21
#
# 2019-02-26T15:40:00Z,1019.39
#
# 2019-02-26T15:50:00Z,1019.53
#
# 2019-02-26T16:00:00Z,1019.61
#
# 2019-02-26T16:10:00Z,1019.76
#
# 2019-02-26T16:20:00Z,1019.86
#
# 2019-02-26T16:30:00Z,1019.99
#
# %%ATRH
#
# %%BARO
#
# DT,BP
#
# 2019-02-26T16:40:00Z,1020.16
#
# 2019-02-26T16:50:00Z,1020.32
#
# 2019-02-26T17:00:00Z,1020.43
#
# 2019-02-26T17:10:00Z,1020.47
#
# 2019-02-26T17:20:00Z,1020.55
#
# 2019-02-26T17:30:00Z,1020.51
#
# 2019-02-26T17:40:00Z,1020.58
#
# 2019-02-26T17:50:00Z,1020.68
#
# 2019-02-26T18:00:00Z,1020.63
#
# 2019-02-26T18:10:00Z,1020.68
#
# ...
