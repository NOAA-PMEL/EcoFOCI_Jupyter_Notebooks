# %% [markdown]
# # SWOT Submitted Data Validation
#
# Ingest all submitted SWOT files and plot for own sanity sake
# - CND -> salinity
# - Temperature
# - as functions of depth
#
# gps lat/ gps lon compared to deployed location + radius of operation

# %%
import xarray as xa

# %%
xdf_jpl = xa.load_dataset('PMEL_SWOTtest_dataset.nc')
xdf_jpl
# Out:
# <xarray.Dataset>
# Dimensions:                 (TIME: 112671, LATITUDE: 1, LONGITUDE: 1,
#                              TIME_SURFACE_BUOY: 289)
# Coordinates:
#   * TIME                    (TIME) datetime64[ns] 2020-01-01T00:25:47 ... 202...
#   * LATITUDE                (LATITUDE) float64 47.61
#   * LONGITUDE               (LONGITUDE) float64 -122.3
#   * TIME_SURFACE_BUOY       (TIME_SURFACE_BUOY) datetime64[ns] 2020-01-02T00:...
# Data variables:
#     PRES                    (TIME) float64 3.53 3.27 3.36 ... 475.4 483.4 0.27
#     TEMP                    (TIME) float64 14.68 14.76 14.75 ... 5.532 0.022
#     CNDC                    (TIME) float64 39.91 40.36 40.38 ... 33.39 0.04
#     INSTR_INFO              |S1 b''
#     INSTR_MAKE              |S19 b'Sea-Bird Scientific'
#     INSTR_MODEL             |S5 b'GPCTD'
#     INSTR_SN                int64 0
#     LATITUDE_SURFACE_BUOY   (TIME_SURFACE_BUOY) float64 36.04 36.03 ... 48.1
# ...

# %%
xdf_jpl.PRES.plot()

# %%
# Map of Deploy Locationa and GPS data
import cartopy
