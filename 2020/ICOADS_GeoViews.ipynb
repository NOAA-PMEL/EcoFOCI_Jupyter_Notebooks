# %%
import pandas as pd
import geopandas as gpd
import fiona 
#import geoviews as gv
#import geoviews.feature as gf
import holoviews as hv
from bokeh.models import HoverTool
# Adds %%opts line magic for bokeh plot config
hv.extension('bokeh')
import hvplot.pandas
from holoviews import streams
from holoviews import opts
import panel as pn
pn.extension()
#import utility as u
import numpy as np
import datetime
import colorcet as cc
import param
#import cartopy
#from cartopy import crs
import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-dda776118805> in <module>
#       2 import geopandas as gpd
#       3 import fiona
# ----> 4 import geoviews as gv
#       5 #import geoviews.feature as gf
#       6 import holoviews as hv
#
# ModuleNotFoundError: No module named 'geoviews'

# %%
# !conda install geoviews

# %%
df = pd.read_csv('/Users/bell/in_and_outbox/2020/wood/IMMA_1940s/datasets_IMMA_ICOADS_ncei_1940s_e044_89bd_5d26.csv',header=0,skiprows=[1],parse_dates=True,index_col='time')
# Out:
# /Users/bell/miniconda3/envs/holoviz/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_1943 = df['1943-03-20':'1943-03-30']
df_1943 = df_1943[(df_1943.longitude >= 162) & (df_1943.longitude <= 175) & (df_1943.latitude >= 50) & (df_1943.latitude <= 60)]
#df_1943.to_csv('19430320-0330_komand.csv')

df_1943.groupby('ID').groups
# Out:
# {'12492': DatetimeIndex(['1943-03-20 20:00:00+00:00', '1943-03-21 00:00:00+00:00',
#                 '1943-03-21 20:00:00+00:00', '1943-03-22 08:00:00+00:00',
#                 '1943-03-22 20:00:00+00:00', '1943-03-23 00:00:00+00:00',
#                 '1943-03-23 09:00:00+00:00', '1943-03-23 21:00:00+00:00',
#                 '1943-03-24 01:00:00+00:00', '1943-03-24 09:00:00+00:00',
#                 '1943-03-24 21:00:00+00:00', '1943-03-25 01:00:00+00:00',
#                 '1943-03-25 09:00:00+00:00', '1943-03-25 21:00:00+00:00',
#                 '1943-03-26 01:00:00+00:00', '1943-03-26 09:00:00+00:00',
#                 '1943-03-27 01:00:00+00:00'],
#                dtype='datetime64[ns, UTC]', name='time', freq=None)}

# %%
df_1943 = df['1943-05':'1943-05']
df_1943 = df_1943[(df_1943.longitude >= 162) & (df_1943.longitude <= 180) & (df_1943.latitude >= 50) & (df_1943.latitude <= 60)]
#df_1943.to_csv('194305_attu.csv')

df_1943.groupby('ID').groups
# Out:
# {'01036': DatetimeIndex(['1943-05-07 20:00:00+00:00', '1943-05-08 00:00:00+00:00',
#                 '1943-05-08 08:00:00+00:00', '1943-05-08 20:00:00+00:00',
#                 '1943-05-09 00:00:00+00:00', '1943-05-09 08:00:00+00:00',
#                 '1943-05-09 21:00:00+00:00', '1943-05-10 01:00:00+00:00',
#                 '1943-05-10 09:00:00+00:00', '1943-05-15 21:00:00+00:00',
#                 '1943-05-16 01:00:00+00:00', '1943-05-16 09:00:00+00:00',
#                 '1943-05-16 21:00:00+00:00', '1943-05-17 01:00:00+00:00',
#                 '1943-05-17 09:00:00+00:00'],
#                dtype='datetime64[ns, UTC]', name='time', freq=None),
#  '01038': DatetimeIndex(['1943-05-11 20:00:00+00:00', '1943-05-12 00:00:00+00:00',
#                 '1943-05-12 08:00:00+00:00', '1943-05-12 20:00:00+00:00',
#                 '1943-05-13 00:00:00+00:00', '1943-05-13 08:00:00+00:00',
#                 '1943-05-13 20:00:00+00:00', '1943-05-14 00:00:00+00:00',
# ...

# %%
df_1941 = df['1941-1':'1941-12'] #just not a lot of data and mostly around australia

df_1944 = df['1944-12-15':'1944-12-20']
df_1944 = df_1944[(df_1944.longitude >= 104) & (df_1944.longitude <= 150) & (df_1944.latitude >= -8) & (df_1944.latitude <= 32)]
df_1944.to_csv('194412_SCSea.csv')
# Out:
# /Users/bell/opt/miniconda3/envs/holoviz/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_1943
# Out:
# /Users/bell/opt/miniconda3/envs/holoviz/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                            latitude  longitude     ID         AT          SLP  \
# time
# 1944-12-15 00:00:00+00:00      52.5      182.5  06009   3.900000   990.200012
# 1944-12-15 00:00:00+00:00      45.5      302.5  22271   3.900000  1005.099976
# 1944-12-15 00:00:00+00:00      45.5      302.5  32070   4.400000  1000.299988
# 1944-12-15 00:00:00+00:00      38.5      297.5  14384  18.299999  1003.400024
# 1944-12-15 00:00:00+00:00      33.5      294.5  59015  16.700001  1014.599976
# ...                             ...        ...    ...        ...          ...
# ...

# %%
sst = gv.Dataset(df_1943,['SST'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ff3cb0d7e8f0> in <module>
# ----> 1 sst = gv.Dataset(df_1943,['SST'])
#
# NameError: name 'gv' is not defined

# %%
points = sst.to(gv.Points, ['longitude', 'latitude'], ['SST'])
# Out:
# /Users/bell/opt/miniconda3/envs/holoviz/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tiles * points.opts(
    color='SST', cmap='viridis',
    tools=['hover'], global_extent=True, width=1200, height=600)
# Out:
# /Users/bell/opt/miniconda3/envs/holoviz/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [longitude,latitude]   (SST)
