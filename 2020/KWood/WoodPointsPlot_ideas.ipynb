# %% [markdown]
# # MAP of Points for KWood
#
# cartopy projections - https://scitools.org.uk/cartopy/docs/latest/crs/projections.html#

# %%
import pandas as pd
import numpy as np

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import matplotlib.pyplot as plt
import matplotlib.path as mpath

# %%
points=pd.read_csv('Unique_posns.txt',header=None,names=['lat','lon'],delimiter='\t')
extent=[-180, 180, -90, 90]

# %%
projection=ccrs.Robinson()

land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m',
                                                edgecolor='face',
                                                facecolor='1.0')

ocean_50m = cfeature.NaturalEarthFeature('physical', 'ocean', '50m',
                                                edgecolor='face',
                                                facecolor='1.0')

fig, ax = plt.subplots(figsize=(24,12), subplot_kw=dict(projection=projection))

ax.set_global()

ax.add_feature(land_50m,color='#7b7975')
ax.add_feature(ocean_50m,color='#738ea2')

ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)

# %%
projection=ccrs.EquidistantConic()

fig, ax = plt.subplots(figsize=(24,12), subplot_kw=dict(projection=projection))
ax.set_global()
ax.add_feature(land_50m,color='#7b7975')
ax.add_feature(ocean_50m,color='#738ea2')

ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)

# %%
projection=ccrs.Mollweide()

fig, ax = plt.subplots(figsize=(24,12), subplot_kw=dict(projection=projection))
ax.set_global()
ax.add_feature(land_50m,color='#7b7975')
ax.add_feature(ocean_50m,color='#738ea2')

ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)

# %%
projection=ccrs.Stereographic()

fig, ax = plt.subplots(figsize=(24,12), subplot_kw=dict(projection=projection))
ax.set_global()
ax.add_feature(land_50m,color='#7b7975')
ax.add_feature(ocean_50m,color='#738ea2')

ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)

# %%
projection=ccrs.InterruptedGoodeHomolosine()

fig, ax = plt.subplots(figsize=(24,12), subplot_kw=dict(projection=projection))
ax.set_global()
ax.add_feature(land_50m,color='#7b7975')
ax.add_feature(ocean_50m,color='#738ea2')

ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)

# %%
projection=ccrs.RotatedPole()

fig, ax = plt.subplots(figsize=(24,12), subplot_kw=dict(projection=projection))
ax.set_global()
ax.add_feature(land_50m,color='#7b7975')
ax.add_feature(ocean_50m,color='#738ea2')

ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)

# %%
projection=ccrs.LambertAzimuthalEqualArea(central_longitude=220.0)

fig, ax = plt.subplots(figsize=(24,12), subplot_kw=dict(projection=projection))
ax.set_global()
ax.add_feature(land_50m,color='#7b7975')
ax.add_feature(ocean_50m,color='#738ea2')

ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)

# %%
projection=ccrs.NorthPolarStereo()

fig, ax = plt.subplots(figsize=(24,12), subplot_kw=dict(projection=projection))
#ax.set_global()
ax.add_feature(ocean_50m,color='#738ea2')
ax.add_feature(land_50m,color='#7b7975')

ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)

# %%
def make_map(projection=ccrs.PlateCarree()):
    fig, ax = plt.subplots(figsize=(24, 24),
                           subplot_kw=dict(projection=projection))
    if projection == ccrs.PlateCarree():
        gl = ax.gridlines(draw_labels=True)
        gl.xlabels_top = gl.ylabels_right = False
        gl.xformatter = LONGITUDE_FORMATTER
        gl.yformatter = LATITUDE_FORMATTER
    return fig, ax

projection=ccrs.NorthPolarStereo(true_scale_latitude=0)
transformation=ccrs.PlateCarree()
fig,ax = make_map(projection=projection)

# Compute a circle in axes coordinates, which we can use as a boundary
# for the map. We can pan/zoom as much as we like - the boundary will be
# permanently circular.
theta = np.linspace(0, 2*np.pi, 10000)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)

ax.set_boundary(circle, transform=ax.transAxes)
ax.gridlines(zorder=3)
ax.add_feature(ocean_50m,color='#738ea2')
ax.add_feature(land_50m,color='#7b7975')


ax.scatter(points.lon,points.lat,s=1,facecolor='#ffd700',linewidth=0.005,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)
ax.scatter(points.lon,points.lat*0,s=1,facecolor='#ffffff',linewidth=0.000,edgecolors='k',transform=ccrs.PlateCarree(),zorder=3)
