# %% [markdown]
# ### SBD Stitcher Program for Popup Buoys
#
# Allows the retrieval of a specific file but not fully implemented wget

# %%
source_url = 'http://eclipse.pmel.noaa.gov/sbd/data/ecofoci.popupsbd/'

# %% [markdown]
# ***Unix command line for cronjobs***
#
# `wget http://eclipse.pmel.noaa.gov/sbd/data/ecofoci.popupsbd/ -np -r -nc -R "index.html*"`

# %% [markdown]
# ### Test reassembly of files

# %%
import os
import glob #python >= 3.5

# %%
# read hex incoded binary
def HexView(file):
    with open(file, 'rb') as in_file:
        while True:
            hexdata = in_file.read().hex().upper()     # Read the shortest possible line
            if len(hexdata) == 0:                      # breaks loop once no more binary data is read
                break
            
            return(hexdata.upper())

# convert identifying bytes for processing
def HexIdent(hexstr):
    if hexstr[0:4] == '0001':
        message_source = 'summary.txt'
    elif hexstr[0:4] == '0002':
        message_source = 'prodat.txt'
    elif hexstr[0:4] == '0003':
        message_source = 'icedat.txt'
    elif hexstr[0:4] == '0004':
        message_source = 'botdat.txt'
    elif hexstr[0:4] == 'FFFE':
        message_source = 'sstdat.txt'        
    else:
        message_source = 'image{}.txt'.format(int(hexstr[0:4],16))        
        
    return(message_source)        
        
def Summary(hexstr):
    '''SUMMARY.TXT'''
    
    PositionInFile = int(hexstr[4:12],16)
    ProfileDataSize = int(hexstr[12:20],16)
    IceDataSize = int(hexstr[20:28],16) 
    BottomDataSize = int(hexstr[28:36],16)
    NumberofImages = int(hexstr[36:40],16)
    
    return({'PositionInFile':PositionInFile, 'ProfileDataSize':ProfileDataSize, 
            'IceDataSize': IceDataSize, 'BottomDataSize':BottomDataSize, 'NumberofImages':NumberofImages})

def Data(hexstr):
    ''' PRODAT.TXT
        ICEDAT.TXT
        SSTDAT.TXT
        BOTDAT.TXT
    '''
    
    PositionInFile = int(hexstr[4:12],16)
    Data = hexstr[12:]
    
    return(PositionInFile, Data)

def Image(file):
    '''{IMAGENUMER}.JPG'''
    
    with open(file, 'rb') as in_file:
        while True:
            header = in_file.read(8).hex()
            hexdata = in_file.read()     # Read the shortest possible line
            if len(hexdata) == 0:                      # breaks loop once no more binary data is read
                break
            
            return(header,hexdata)

# %%
#list id's in download path
root_path = '/Volumes/WDC_internal/Users/bell/ecoraid/2018/Additional_FieldData/Popup_Buoys/eclipse.pmel.noaa.gov/sbd/data/ecofoci.popupsbd/'

id_dir = os.listdir(root_path)
id_dir
# Out:
# ['300434063823800',
#  '300434063826810',
#  '300434063921240',
#  '300434063925210',
#  '300434063928220',
#  'files']

# %%
# cycle through each id
#  Within each ID is a sequential transmission number.  Within the transmissions there may be multiple
#   sample periods.  Unfortunately, the only way to identify these is when a file restarts and the 
#   byte position is 0.  Thus, to get the most recent (and therefore most likely desired) sample period
#   one must progress in reverse order through the files to find the transimission number with a 0 position.

begin_index = {}
for msg_id_dir in id_dir:
    for filename in sorted(glob.iglob(root_path + msg_id_dir + '/**/*.sbd*', recursive=True), reverse=True):
        hexstr = HexView(filename)
        
        if (HexIdent(hexstr)) == 'summary.txt':
            begin_index.update({msg_id_dir: filename.split('.sbd')[0]})
            break
            
for msg_id_dir in id_dir:
    
    if not os.path.exists(msg_id_dir):
        os.makedirs(msg_id_dir)
    read_datafiles=False
    
    for filename in glob.iglob(root_path + msg_id_dir + '/**/*.sbd*', recursive=True):
        
        try: 
            if filename.split('.sbd')[0] == begin_index[msg_id_dir]:
                read_datafiles = True
        except KeyError:
            print("Directory {} does not have a summary file".format(msg_id_dir))
            
        if not read_datafiles:
            continue
            
        print(filename.split('ecofoci.popupsbd')[-1])
        
        hexstr = HexView(filename)
        
        if (HexIdent(hexstr)) == 'summary.txt':
            print(Summary(hexstr))
            
        elif (HexIdent(hexstr)) == 'prodat.txt':
            position,outstr = Data(hexstr)
            
            #open file, seek, write
            with open(msg_id_dir+'/PRODAT.TXT', 'ab+') as out_file:
                out_file.seek(position, 0)
                out_file.write( bytes.fromhex(outstr))               
                
        elif (HexIdent(hexstr)) == 'sstdat.txt':
            position,outstr = Data(hexstr)
            
            #open file, seek, write
            with open(msg_id_dir+'/SSTDAT.TXT', 'ab+') as out_file:
                out_file.seek(position, 0)
                out_file.write( bytes.fromhex(outstr))
                
        elif (HexIdent(hexstr)) == 'icedat.txt':
            position,outstr = Data(hexstr)
            
            #open file, seek, write
            with open(msg_id_dir+'/ICEDAT.TXT', 'ab+') as out_file:
                out_file.seek(position, 0)
                out_file.write( bytes.fromhex(outstr))

        elif (HexIdent(hexstr)) == 'botdat.txt':
            position,outstr = Data(hexstr)
            
            #open file, seek, write
            with open(msg_id_dir+'/BOTDAT.TXT', 'ab+') as out_file:
                out_file.seek(position, 0)
                out_file.write( bytes.fromhex(outstr))
                
        else:

            print("image file")
            header, hexdata = Image(filename)

            try:
                
                with open(msg_id_dir+'/{:05d}.jpg'.format(int(header[12:16],16)), 'rb+') as out_file:
                    out_file.seek(int(header[4:12],16), 0)
                    out_file.write((hexdata))
                    
            except FileNotFoundError:
                
                with open(msg_id_dir+'/{:05d}.jpg'.format(int(header[12:16],16)), 'wb+') as out_file:
                    out_file.seek(int(header[4:12],16), 0)
                    out_file.write((hexdata))
# Out:
# Directory 300434063823800 does not have a summary file
# Directory 300434063823800 does not have a summary file
# Directory 300434063823800 does not have a summary file
# /300434063826810/2018/300434063826810_000001.sbd.180831_104302
# {'PositionInFile': 0, 'ProfileDataSize': 4727, 'IceDataSize': 357, 'BottomDataSize': 289, 'NumberofImages': 0}
# /300434063826810/2018/300434063826810_000002.sbd.180831_104317
# /300434063826810/2018/300434063826810_000003.sbd.180831_104328
# /300434063826810/2018/300434063826810_000004.sbd.180831_104338
# /300434063826810/2018/300434063826810_000005.sbd.180831_104351
# /300434063826810/2018/300434063826810_000006.sbd.180831_104400
# /300434063826810/2018/300434063826810_000007.sbd.180831_104408
# /300434063921240/test/300434063921240_000113.sbd.180722_133620
# {'PositionInFile': 0, 'ProfileDataSize': 4727, 'IceDataSize': 55, 'BottomDataSize': 238, 'NumberofImages': 1}
# /300434063921240/test/300434063921240_000113.sbd.180723_083851
# {'PositionInFile': 0, 'ProfileDataSize': 4727, 'IceDataSize': 55, 'BottomDataSize': 238, 'NumberofImages': 1}
# /300434063921240/test/300434063921240_000113.sbd.180725_152345
# {'PositionInFile': 0, 'ProfileDataSize': 4727, 'IceDataSize': 55, 'BottomDataSize': 238, 'NumberofImages': 1}
# /300434063921240/test/300434063921240_000114.sbd.180722_133632
# /300434063921240/test/300434063921240_000114.sbd.180723_083851
# /300434063921240/test/300434063921240_000114.sbd.180725_152345
# /300434063921240/test/300434063921240_000115.sbd.180722_133841
# /300434063921240/test/300434063921240_000115.sbd.180723_083851
# /300434063921240/test/300434063921240_000115.sbd.180725_152345
# /300434063921240/test/300434063921240_000116.sbd.180722_151743
# image file
# /300434063921240/test/300434063921240_000116.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000116.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000117.sbd.180722_152259
# /300434063921240/test/300434063921240_000117.sbd.180723_083851
# /300434063921240/test/300434063921240_000117.sbd.180725_152345
# /300434063921240/test/300434063921240_000118.sbd.180722_152308
# /300434063921240/test/300434063921240_000118.sbd.180723_083851
# /300434063921240/test/300434063921240_000118.sbd.180725_152345
# /300434063921240/test/300434063921240_000119.sbd.180722_152331
# /300434063921240/test/300434063921240_000119.sbd.180723_083851
# /300434063921240/test/300434063921240_000119.sbd.180725_152345
# /300434063921240/test/300434063921240_000120.sbd.180722_152339
# /300434063921240/test/300434063921240_000120.sbd.180723_083851
# /300434063921240/test/300434063921240_000120.sbd.180725_152345
# /300434063921240/test/300434063921240_000121.sbd.180722_152348
# /300434063921240/test/300434063921240_000121.sbd.180723_083851
# /300434063921240/test/300434063921240_000121.sbd.180725_152345
# /300434063921240/test/300434063921240_000122.sbd.180722_152358
# /300434063921240/test/300434063921240_000122.sbd.180723_083851
# /300434063921240/test/300434063921240_000122.sbd.180725_152345
# /300434063921240/test/300434063921240_000123.sbd.180722_152405
# /300434063921240/test/300434063921240_000123.sbd.180723_083851
# /300434063921240/test/300434063921240_000123.sbd.180725_152345
# /300434063921240/test/300434063921240_000124.sbd.180722_152414
# /300434063921240/test/300434063921240_000124.sbd.180723_083851
# /300434063921240/test/300434063921240_000124.sbd.180725_152345
# /300434063921240/test/300434063921240_000125.sbd.180722_152423
# /300434063921240/test/300434063921240_000125.sbd.180723_083851
# /300434063921240/test/300434063921240_000125.sbd.180725_152345
# /300434063921240/test/300434063921240_000126.sbd.180722_152431
# /300434063921240/test/300434063921240_000126.sbd.180723_083851
# /300434063921240/test/300434063921240_000126.sbd.180725_152345
# /300434063921240/test/300434063921240_000127.sbd.180722_152441
# /300434063921240/test/300434063921240_000127.sbd.180723_083851
# /300434063921240/test/300434063921240_000127.sbd.180725_152345
# /300434063921240/test/300434063921240_000128.sbd.180722_152449
# /300434063921240/test/300434063921240_000128.sbd.180723_083851
# /300434063921240/test/300434063921240_000128.sbd.180725_152345
# /300434063921240/test/300434063921240_000129.sbd.180722_152457
# /300434063921240/test/300434063921240_000129.sbd.180723_083851
# /300434063921240/test/300434063921240_000129.sbd.180725_152345
# /300434063921240/test/300434063921240_000130.sbd.180722_152505
# /300434063921240/test/300434063921240_000130.sbd.180723_083851
# /300434063921240/test/300434063921240_000130.sbd.180725_152345
# /300434063921240/test/300434063921240_000131.sbd.180722_152513
# /300434063921240/test/300434063921240_000131.sbd.180723_083851
# /300434063921240/test/300434063921240_000131.sbd.180725_152345
# /300434063921240/test/300434063921240_000132.sbd.180722_152523
# /300434063921240/test/300434063921240_000132.sbd.180723_083851
# /300434063921240/test/300434063921240_000132.sbd.180725_152345
# /300434063921240/test/300434063921240_000133.sbd.180722_152533
# image file
# /300434063921240/test/300434063921240_000133.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000133.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000134.sbd.180722_152542
# image file
# /300434063921240/test/300434063921240_000134.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000134.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000135.sbd.180722_152555
# image file
# /300434063921240/test/300434063921240_000135.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000135.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000136.sbd.180722_152608
# image file
# /300434063921240/test/300434063921240_000136.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000136.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000137.sbd.180722_152624
# image file
# /300434063921240/test/300434063921240_000137.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000137.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000138.sbd.180722_152638
# image file
# /300434063921240/test/300434063921240_000138.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000138.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000139.sbd.180722_152654
# image file
# /300434063921240/test/300434063921240_000139.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000139.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000140.sbd.180722_153016
# image file
# /300434063921240/test/300434063921240_000140.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000140.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000141.sbd.180722_153132
# /300434063921240/test/300434063921240_000141.sbd.180723_083851
# /300434063921240/test/300434063921240_000141.sbd.180725_152345
# /300434063921240/test/300434063921240_000142.sbd.180722_170305
# image file
# /300434063921240/test/300434063921240_000142.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000142.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000143.sbd.180722_170316
# /300434063921240/test/300434063921240_000143.sbd.180723_083851
# /300434063921240/test/300434063921240_000143.sbd.180725_152345
# /300434063921240/test/300434063921240_000144.sbd.180722_200132
# image file
# /300434063921240/test/300434063921240_000144.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000144.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000145.sbd.180722_200141
# /300434063921240/test/300434063921240_000145.sbd.180723_083851
# /300434063921240/test/300434063921240_000145.sbd.180725_152345
# /300434063921240/test/300434063921240_000146.sbd.180722_230133
# image file
# /300434063921240/test/300434063921240_000146.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000146.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000147.sbd.180722_230142
# /300434063921240/test/300434063921240_000147.sbd.180723_083851
# /300434063921240/test/300434063921240_000147.sbd.180725_152345
# /300434063921240/test/300434063921240_000148.sbd.180723_020230
# image file
# /300434063921240/test/300434063921240_000148.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000148.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000149.sbd.180723_020238
# /300434063921240/test/300434063921240_000149.sbd.180723_083851
# /300434063921240/test/300434063921240_000149.sbd.180725_152345
# /300434063921240/test/300434063921240_000150.sbd.180723_050150
# image file
# /300434063921240/test/300434063921240_000150.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000150.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000151.sbd.180723_050159
# /300434063921240/test/300434063921240_000151.sbd.180723_083851
# /300434063921240/test/300434063921240_000151.sbd.180725_152345
# /300434063921240/test/300434063921240_000152.sbd.180723_080232
# image file
# /300434063921240/test/300434063921240_000152.sbd.180723_083851
# image file
# /300434063921240/test/300434063921240_000152.sbd.180725_152345
# image file
# /300434063921240/test/300434063921240_000153.sbd.180723_080243
# /300434063921240/test/300434063921240_000153.sbd.180723_083817
# /300434063921240/test/300434063921240_000153.sbd.180723_083851
# /300434063921240/test/300434063921240_000153.sbd.180725_152345
# /300434063925210/2018/300434063925210_000001.sbd.180831_090648
# {'PositionInFile': 0, 'ProfileDataSize': 4727, 'IceDataSize': 17, 'BottomDataSize': 289, 'NumberofImages': 0}
# /300434063925210/2018/300434063925210_000002.sbd.180831_090658
# /300434063925210/2018/300434063925210_000003.sbd.180831_090711
# /300434063925210/2018/300434063925210_000004.sbd.180831_090724
# /300434063925210/2018/300434063925210_000005.sbd.180831_090746
# /300434063925210/2018/300434063925210_000006.sbd.180831_103313
# image file
# /300434063925210/2018/300434063925210_000007.sbd.180831_103323
# /300434063925210/2018/300434063925210_000008.sbd.180831_103354
# /300434063925210/2018/300434063925210_000009.sbd.180831_103405
# /300434063925210/2018/300434063925210_000010.sbd.180831_103419
# /300434063925210/2018/300434063925210_000011.sbd.180831_103431
# /300434063925210/2018/300434063925210_000012.sbd.180831_103457
# /300434063925210/2018/300434063925210_000013.sbd.180831_103613
# /300434063925210/2018/300434063925210_000014.sbd.180831_103622
# /300434063925210/2018/300434063925210_000015.sbd.180831_103631
# /300434063925210/2018/300434063925210_000016.sbd.180831_103640
# /300434063925210/2018/300434063925210_000017.sbd.180831_103656
# /300434063925210/2018/300434063925210_000018.sbd.180831_103707
# /300434063925210/2018/300434063925210_000019.sbd.180831_103729
# /300434063925210/2018/300434063925210_000020.sbd.180831_104146
# image file
# /300434063925210/2018/300434063925210_000021.sbd.180831_104244
# image file
# /300434063925210/2018/300434063925210_000022.sbd.180831_104254
# image file
# /300434063925210/2018/300434063925210_000023.sbd.180831_104310
# image file
# /300434063925210/2018/300434063925210_000024.sbd.180831_104326
# image file
# /300434063925210/2018/300434063925210_000025.sbd.180831_104344
# image file
# /300434063925210/2018/300434063925210_000026.sbd.180831_104400
# image file
# /300434063925210/2018/300434063925210_000027.sbd.180831_104507
# image file
# /300434063925210/2018/300434063925210_000028.sbd.180831_104520
# image file
# /300434063925210/2018/300434063925210_000029.sbd.180831_104528
# image file
# /300434063925210/2018/300434063925210_000030.sbd.180831_104544
# image file
# /300434063925210/2018/300434063925210_000031.sbd.180831_104552
# image file
# /300434063925210/2018/300434063925210_000032.sbd.180831_104701
# image file
# /300434063925210/2018/300434063925210_000033.sbd.180831_110850
# image file
# /300434063925210/2018/300434063925210_000034.sbd.180831_111040
# image file
# /300434063925210/2018/300434063925210_000035.sbd.180831_111050
# image file
# /300434063925210/2018/300434063925210_000036.sbd.180831_111058
# image file
# /300434063925210/2018/300434063925210_000037.sbd.180831_111107
# image file
# /300434063925210/2018/300434063925210_000038.sbd.180831_111218
# image file
# Directory 300434063928220 does not have a summary file
# Directory files does not have a summary file
# Directory files does not have a summary file
# Directory files does not have a summary file
# Directory files does not have a summary file
# Directory files does not have a summary file
# Directory files does not have a summary file
# Directory files does not have a summary file
# Directory files does not have a summary file
