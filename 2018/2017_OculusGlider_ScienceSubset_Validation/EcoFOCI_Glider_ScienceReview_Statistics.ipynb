# %% [markdown]
# ## Statistics of EcoFOCI Glider Locations from Science Data Set

# %%
import pandas as pd

# %%
output_log = '/Users/bell/Programs/Python/EcoFOCI_OculusGlider/sg401_results.dtdz_1.txt'

df = pd.read_csv(output_log,names=['profile','status'])
df.dropna(inplace=True)

# %%
dfg = df.groupby('status')
dfg.count()
# Out:
#                                       profile
# status
#  "not adjusted"                           697
#  "successfully adjusted"                 2779
#  "unloadable - missing key variable"       89

# %%
dfg.get_group(' "not adjusted"')
# Out:
#           profile           status
# 523   p4010262.nc   "not adjusted"
# 577   p4010289.nc   "not adjusted"
# 581   p4010291.nc   "not adjusted"
# 589   p4010295.nc   "not adjusted"
# 591   p4010296.nc   "not adjusted"
# 609   p4010305.nc   "not adjusted"
# 611   p4010306.nc   "not adjusted"
# 613   p4010307.nc   "not adjusted"
# 631   p4010316.nc   "not adjusted"
# 635   p4010318.nc   "not adjusted"
# 639   p4010320.nc   "not adjusted"
# 647   p4010324.nc   "not adjusted"
# 649   p4010325.nc   "not adjusted"
# 651   p4010326.nc   "not adjusted"
# 653   p4010327.nc   "not adjusted"
# 657   p4010329.nc   "not adjusted"
# 663   p4010332.nc   "not adjusted"
# 665   p4010333.nc   "not adjusted"
# 667   p4010334.nc   "not adjusted"
# 675   p4010338.nc   "not adjusted"
# 687   p4010344.nc   "not adjusted"
# 709   p4010355.nc   "not adjusted"
# 719   p4010360.nc   "not adjusted"
# 733   p4010367.nc   "not adjusted"
# 735   p4010368.nc   "not adjusted"
# 813   p4010407.nc   "not adjusted"
# 833   p4010417.nc   "not adjusted"
# 837   p4010419.nc   "not adjusted"
# 841   p4010421.nc   "not adjusted"
# 845   p4010423.nc   "not adjusted"
# ...           ...              ...
# 6837  p4013466.nc   "not adjusted"
# 6847  p4013471.nc   "not adjusted"
# 6871  p4013483.nc   "not adjusted"
# 6879  p4013487.nc   "not adjusted"
# 6889  p4013492.nc   "not adjusted"
# 6893  p4013494.nc   "not adjusted"
# 6899  p4013497.nc   "not adjusted"
# 6905  p4013500.nc   "not adjusted"
# 6933  p4013514.nc   "not adjusted"
# 6957  p4013526.nc   "not adjusted"
# 6963  p4013529.nc   "not adjusted"
# 6969  p4013532.nc   "not adjusted"
# 6977  p4013536.nc   "not adjusted"
# 6997  p4013546.nc   "not adjusted"
# 7007  p4013551.nc   "not adjusted"
# 7017  p4013556.nc   "not adjusted"
# 7021  p4013558.nc   "not adjusted"
# 7031  p4013563.nc   "not adjusted"
# 7033  p4013564.nc   "not adjusted"
# 7041  p4013568.nc   "not adjusted"
# 7043  p4013569.nc   "not adjusted"
# 7045  p4013570.nc   "not adjusted"
# 7081  p4013588.nc   "not adjusted"
# 7085  p4013590.nc   "not adjusted"
# 7087  p4013591.nc   "not adjusted"
# 7103  p4013599.nc   "not adjusted"
# 7107  p4013601.nc   "not adjusted"
# 7111  p4013603.nc   "not adjusted"
# 7117  p4013606.nc   "not adjusted"
# 7129  p4013612.nc   "not adjusted"
#
# [697 rows x 2 columns]

# %% [markdown]
# ###  Subset - small selection
#
# **Dives 300-399**

# %%
dfs = df[df['profile'].str.contains("p40100")]

# %%
dfs
# Out:
#          profile                                status
# 1    p4010001.nc   "unloadable - missing key variable"
# 3    p4010002.nc   "unloadable - missing key variable"
# 5    p4010003.nc               "successfully adjusted"
# 7    p4010004.nc               "successfully adjusted"
# 9    p4010005.nc               "successfully adjusted"
# 11   p4010006.nc               "successfully adjusted"
# 13   p4010007.nc               "successfully adjusted"
# 15   p4010008.nc               "successfully adjusted"
# 17   p4010009.nc               "successfully adjusted"
# 19   p4010010.nc               "successfully adjusted"
# 21   p4010011.nc               "successfully adjusted"
# 23   p4010012.nc               "successfully adjusted"
# 25   p4010013.nc               "successfully adjusted"
# 27   p4010014.nc               "successfully adjusted"
# 29   p4010015.nc               "successfully adjusted"
# 31   p4010016.nc               "successfully adjusted"
# 33   p4010017.nc               "successfully adjusted"
# 35   p4010018.nc               "successfully adjusted"
# 37   p4010019.nc               "successfully adjusted"
# 39   p4010020.nc               "successfully adjusted"
# 41   p4010021.nc               "successfully adjusted"
# 43   p4010022.nc               "successfully adjusted"
# 45   p4010023.nc               "successfully adjusted"
# 47   p4010024.nc               "successfully adjusted"
# 49   p4010025.nc               "successfully adjusted"
# 51   p4010026.nc               "successfully adjusted"
# 53   p4010027.nc               "successfully adjusted"
# 55   p4010028.nc               "successfully adjusted"
# 57   p4010029.nc               "successfully adjusted"
# 59   p4010030.nc               "successfully adjusted"
# ..           ...                                   ...
# 139  p4010070.nc               "successfully adjusted"
# 141  p4010071.nc               "successfully adjusted"
# 143  p4010072.nc               "successfully adjusted"
# 145  p4010073.nc               "successfully adjusted"
# 147  p4010074.nc               "successfully adjusted"
# 149  p4010075.nc               "successfully adjusted"
# 151  p4010076.nc               "successfully adjusted"
# 153  p4010077.nc               "successfully adjusted"
# 155  p4010078.nc               "successfully adjusted"
# 157  p4010079.nc               "successfully adjusted"
# 159  p4010080.nc               "successfully adjusted"
# 161  p4010081.nc               "successfully adjusted"
# 163  p4010082.nc               "successfully adjusted"
# 165  p4010083.nc               "successfully adjusted"
# 167  p4010084.nc               "successfully adjusted"
# 169  p4010085.nc               "successfully adjusted"
# 171  p4010086.nc               "successfully adjusted"
# 173  p4010087.nc               "successfully adjusted"
# 175  p4010088.nc               "successfully adjusted"
# 177  p4010089.nc               "successfully adjusted"
# 179  p4010090.nc               "successfully adjusted"
# 181  p4010091.nc               "successfully adjusted"
# 183  p4010092.nc               "successfully adjusted"
# 185  p4010093.nc               "successfully adjusted"
# 187  p4010094.nc               "successfully adjusted"
# 189  p4010095.nc               "successfully adjusted"
# 191  p4010096.nc               "successfully adjusted"
# 193  p4010097.nc               "successfully adjusted"
# 195  p4010098.nc               "successfully adjusted"
# 197  p4010099.nc               "successfully adjusted"
#
# [99 rows x 2 columns]

# %%
dfg = dfs.groupby('status')
dfg.count()
# Out:
#                                       profile
# status
#  "successfully adjusted"                   97
#  "unloadable - missing key variable"        2
