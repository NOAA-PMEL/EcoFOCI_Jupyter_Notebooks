# %% [markdown]
# ## Arctic Heat
#
# **AXCTD and XBT Profiles**
#
# Purpose: import clean and plot profiles

# %%
import pandas as pd
import os
import datetime

# %%
source_dir = '/Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/'

source_file = [os.path.join(dp, f) for dp, dn,
   fn in os.walk(os.path.expanduser(source_dir)) for f in fn if 'dta' in f]

# %% [markdown]
# ### Data Ingestion and data summary/statistics
#
# A few lines to list and read the .iwg files into a dictionary of pandas dataframes.
#
# The original .dta files have header as follows:
#
# ```
# Probe Type = AXBT
#        Date = 2018/05/26
#        Time = 00:29:35.620
#
#     Time     Depth    Frequency    (C)       (F)
# ```

# %%
dfs = {}
for i,filename in enumerate(source_file):
    try:
        header = pd.read_csv(filename,nrows=4,header=None)
        
        #parse date in header to add delta-t in columns to
        sd = header[0][1].split('= ')[-1].split('.')
        nofrag, frag = header[0][2].split('= ')[-1].split('.')
        st = datetime.datetime.strptime(sd[0] + ' ' + nofrag,'%Y/%m/%d %H:%M:%S')
        st = st.replace(microsecond=int(frag))
        
        columns = ['Time','Depth','Frequency','DegreeC','DegreeF']
        temp_data = pd.read_csv(filename,delimiter='\s+',skiprows=4,na_values='******')
        temp_data['DateTime'] = [st +datetime.timedelta(seconds=x[1]['Time']) for x in temp_data.iterrows()]
        temp_data = temp_data.set_index(pd.DatetimeIndex(temp_data['DateTime']))
        dfs.update({filename:temp_data})
        print(filename)
    except ValueError:
        print("{} failed to load".format(filename))
        continue
    except KeyError:
        print("{} failed to process time".format(filename))
        continue
# Out:
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180531/15126162_2018_06_01_02_06_11.dta failed to process time
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180531/15126157_2018_06_01_00_22_24.dta failed to process time
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180531/15126161_2018_05_31_23_50_38.dta failed to process time
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180531/15126160_2018_06_01_01_21_03.dta failed to process time
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180531/15126163_2018_06_01_02_15_55.dta failed to process time
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180531/15126156_2018_06_01_00_53_34.dta failed to process time
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180525/log00004.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180525/log00003.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180525/log00002.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180525/log00000.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180525/log00001.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180527/log00003.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180527/log00002.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180527/log00000.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180527/log00001.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00005.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00004.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00006.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00007.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00003.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00002.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00000.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00001.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00009.dta
# /Users/bell/ecoraid/2018/Additional_FieldData/ArcticHeat/AXBT_Data/AXBT_20180529/log00008.dta

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
for ds, df in dfs.items():
    try:
        plt.plot(df['(C)'],df['Depth'])
        plt.ylabel('Depth (m)')
        plt.xlabel('Temperature (degC)')
    except:
        pass
    
ax = plt.gca()
ax.invert_yaxis()

# %%
for ds, df in dfs.items():
    fig = plt.figure()
    try:
        plt.plot(df['(C)'],df['Depth'])
        plt.ylabel('Depth (m)')
        plt.xlabel('Temperature (degC)')
        ax = plt.gca()
        ax.invert_yaxis()
        plt.title(ds)
    except:
        pass
