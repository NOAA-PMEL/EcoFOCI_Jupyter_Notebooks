# %% [markdown]
# # Seabird CTD (.cnv) to CF-Netcdf files for PMEL/EcoFOCI

# %% [markdown]
# __pyversion__ == 3.7
# __author__ == S.Bell
# __date__ == Feb 20, 2019

# %% [markdown]
# *Description*
#
# Using as many community tools as is available, ingest seabird cnv files and output CF/COARDS compliant NetCDF files for archiving and editing.
#
# Standards:
# CF/COARDS (1.7) - http://cfconventions.org/
# ACDD (1.3) - Data Discovery (sits on top of CF standards - http://wiki.esipfed.org/index.php/Attribute_Convention_for_Data_Discovery)
#
# __Meta Information__ should come from sources in the following order:
#
# + cnv files
# + database files (over-rules cnv files when flagged)
# + yaml based config files (over-rules database and cnv files when flagged)

# %%
import ctd
import pandas as pd
import xarray as xa
import yaml

# science stack
import numpy as np

# %% [markdown]
# ## Information
# Read and display the contents of our test file.  The ctd (python-ctd - https://github.com/pyoceans/python-ctd) software will ingest the contents of the cnv file into a pandas table

# %%
test_file = 'data/test'
ctd_df = ctd.DataFrame.from_cnv(test_file+'.cnv')
# Out:
# /Users/bell/anaconda2/envs/py37/lib/python3.7/site-packages/ctd/ctd.py:147: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self.header = header
# /Users/bell/anaconda2/envs/py37/lib/python3.7/site-packages/ctd/ctd.py:149: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self.config = config

# %%
ctd_df.describe()
# Out:
#          c0mS/cm    c1mS/cm  flECO-AFL    sbeox0V      t090C      t190C  \
# count  67.000000  67.000000  67.000000  67.000000  67.000000  67.000000
# mean   29.769978  29.772047   0.789513   2.488628   3.610676   3.610854
# std     0.006822   0.006822   0.089931   0.041992   0.004228   0.004120
# min    29.753597  29.756555   0.482100   2.383500   3.605700   3.605900
# 25%    29.765546  29.767350   0.780450   2.478800   3.607900   3.608100
# 50%    29.768302  29.770389   0.814300   2.504100   3.609000   3.609400
# 75%    29.774869  29.777149   0.838850   2.517750   3.612000   3.612300
# max    29.783384  29.785494   0.883600   2.546700   3.621300   3.621500
#
#            timeS    sbeox1V         par  turbWETntu0  ...      sal11  \
# count   67.00000  67.000000   67.000000    67.000000  ...  67.000000
# mean   341.44903   2.596190   22.771780     0.778700  ...  32.068264
# std     92.84064   0.006939   54.862609     0.239176  ...   0.000206
# min    112.12400   2.582500    0.209830     0.603600  ...  32.067900
# 25%    287.51950   2.591000    0.212345     0.648950  ...  32.068100
# 50%    341.45200   2.595200    1.234100     0.685100  ...  32.068200
# 75%    394.26450   2.601600   13.511500     0.776150  ...  32.068350
# max    543.73200   2.610000  304.010000     1.669700  ...  32.068800
#
#        sigma-t00  sigma-t11  sbeox0ML/L  sbox0Mm/Kg    sbeox0PS  sbeox1ML/L  \
# count  67.000000  67.000000   67.000000   67.000000   67.000000   67.000000
# mean   25.489587  25.491396    7.245030  315.520418   97.113104    7.308734
# std     0.000442   0.000454    0.145682    6.344420    1.956144    0.009740
# min    25.488600  25.490200    6.878000  299.536000   92.190000    7.283400
# 25%    25.489500  25.491250    7.236000  315.127500   96.987500    7.302500
# 50%    25.489700  25.491500    7.297300  317.799000   97.818000    7.308600
# 75%    25.489900  25.491700    7.328000  319.135000   98.227000    7.315450
# max    25.490400  25.492300    7.533600  328.086000  100.977000    7.332100
#
#        sbox1Mm/Kg   sbeox1PS       nbin
# count   67.000000  67.000000  67.000000
# mean   318.294388  97.968955  36.985075
# std      0.423840   0.135408  16.090174
# min    317.191000  97.628000  14.000000
# 25%    318.024000  97.886000  25.500000
# 50%    318.290000  97.966000  35.000000
# 75%    318.586500  98.056000  44.500000
# max    319.312000  98.302000  95.000000
#
# [8 rows x 21 columns]

# %%
rossum = ctd.rosette_summary(test_file+'.ros')
rossum.groupby(rossum.bpos)['t090C', 't190C', 'c0mS/cm', 'c1mS/cm', 'depSM'].mean()
# Out:
#          t090C     t190C    c0mS/cm    c1mS/cm      depSM
# bpos
# 1     3.609163  3.609482  29.782319  29.784502  64.804408
# 2     3.609247  3.609541  29.782231  29.784364  64.552878
# 3     3.609673  3.610008  29.776660  29.778806  50.764306
# 4     3.609122  3.609414  29.772157  29.774314  41.653102
# 5     3.611108  3.611592  29.768367  29.770653  29.452673
# 6     3.611212  3.611373  29.767733  29.769850  27.565694
# 7     3.611386  3.612029  29.767226  29.769664  26.311959
# 8     3.632188  3.632131  29.779031  29.780918  14.123327
# 9     3.618300  3.620363  29.765324  29.768815   9.006898
# 10    3.626857  3.627402  29.770237  29.772524   3.911878

# %% [markdown]
# ## The following is the meta information in the cnv files

# %%
print("Metadata from Header")
print("lon:{longitude}".format(longitude=ctd_df.longitude))
print("lat:{latitude}".format(latitude=ctd_df.latitude))
print("time:{time}".format(time=ctd_df.time))
# Out:
# Metadata from Header
# lon:-164.05033333333333
# lat:56.871833333333335
# time:2018-04-30 19:11:51

# %%
print("name:{name}".format(name=ctd_df.name))
# Out:
# name:data

# %%
ctd_df.config
# Out:
# ['# nquan = 23',
#  '# nvalues = 67',
#  '# units = specified',
#  '# name 0 = c0mS/cm: Conductivity [mS/cm]',
#  '# name 1 = c1mS/cm: Conductivity, 2 [mS/cm]',
#  '# name 2 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]',
#  '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]',
#  '# name 4 = t090C: Temperature [ITS-90, deg C]',
#  '# name 5 = t190C: Temperature, 2 [ITS-90, deg C]',
#  '# name 6 = timeS: Time, Elapsed [seconds]',
#  '# name 7 = prDM: Pressure, Digiquartz [db]',
#  '# name 8 = sbeox1V: Oxygen raw, SBE 43, 2 [V]',
#  '# name 9 = par: PAR/Irradiance, Biospherical/Licor',
#  '# name 10 = turbWETntu0: Turbidity, WET Labs ECO [NTU]',
#  '# name 11 = sal00: Salinity, Practical [PSU]',
#  '# name 12 = sal11: Salinity, Practical, 2 [PSU]',
#  '# name 13 = sigma-t00: Density [sigma-t, kg/m^3 ]',
#  '# name 14 = sigma-t11: Density, 2 [sigma-t, kg/m^3 ]',
#  '# name 15 = sbeox0ML/L: Oxygen, SBE 43 [ml/l], WS = 2',
#  '# name 16 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg], WS = 2',
#  '# name 17 = sbeox0PS: Oxygen, SBE 43 [% saturation], WS = 2',
#  '# name 18 = sbeox1ML/L: Oxygen, SBE 43, 2 [ml/l], WS = 2',
#  '# name 19 = sbox1Mm/Kg: Oxygen, SBE 43, 2 [umol/kg], WS = 2',
#  '# name 20 = sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS = 2',
#  '# name 21 = nbin: number of scans per bin',
#  '# name 22 = flag: flag',
#  '# span 0 =  29.753597,  29.783384',
#  '# span 1 =  29.756555,  29.785494',
#  '# span 2 =     0.4821,     0.8836',
#  '# span 3 =     2.3835,     2.5467',
#  '# span 4 =     3.6057,     3.6213',
#  '# span 5 =     3.6059,     3.6215',
#  '# span 6 =    112.124,    543.732',
#  '# span 7 =      1.000,     67.000',
#  '# span 8 =     2.5825,     2.6100',
#  '# span 9 = 2.0983e-01, 3.0401e+02',
#  '# span 10 =     0.6036,     1.6697',
#  '# span 11 =    32.0652,    32.0664',
#  '# span 12 =    32.0679,    32.0688',
#  '# span 13 =    25.4886,    25.4904',
#  '# span 14 =    25.4902,    25.4923',
#  '# span 15 =     6.8780,     7.5336',
#  '# span 16 =    299.536,    328.086',
#  '# span 17 =     92.190,    100.977',
#  '# span 18 =     7.2834,     7.3321',
#  '# span 19 =    317.191,    319.312',
#  '# span 20 =     97.628,     98.302',
#  '# span 21 =         14,         95',
#  '# span 22 = 0.0000e+00, 0.0000e+00',
#  '# interval = decibars: 1',
#  '# start_time = Apr 30 2018 19:11:51 [NMEA time, header]',
#  '# bad_flag = -9.990e-29',
#  '# <Sensors count="13" >',
#  '#   <sensor Channel="1" >',
#  '#     <!-- Frequency 0, Temperature -->',
#  '#     <TemperatureSensor SensorID="55" >',
#  '#       <SerialNumber>4379</SerialNumber>',
#  '#       <CalibrationDate>14-Dec-17</CalibrationDate>',
#  '#       <UseG_J>1</UseG_J>',
#  '#       <A>0.00000000e+000</A>',
#  '#       <B>0.00000000e+000</B>',
#  '#       <C>0.00000000e+000</C>',
#  '#       <D>0.00000000e+000</D>',
#  '#       <F0_Old>0.000</F0_Old>',
#  '#       <G>4.37162277e-003</G>',
#  '#       <H>6.46682382e-004</H>',
#  '#       <I>2.27049724e-005</I>',
#  '#       <J>1.86789676e-006</J>',
#  '#       <F0>1000.000</F0>',
#  '#       <Slope>1.00000000</Slope>',
#  '#       <Offset>0.0000</Offset>',
#  '#     </TemperatureSensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="2" >',
#  '#     <!-- Frequency 1, Conductivity -->',
#  '#     <ConductivitySensor SensorID="3" >',
#  '#       <SerialNumber>042985</SerialNumber>',
#  '#       <CalibrationDate>14-Dec-17</CalibrationDate>',
#  '#       <UseG_J>1</UseG_J>',
#  '#       <!-- Cell const and series R are applicable only for wide range sensors. -->',
#  '#       <SeriesR>0.0000</SeriesR>',
#  '#       <CellConst>2000.0000</CellConst>',
#  '#       <ConductivityType>0</ConductivityType>',
#  '#       <Coefficients equation="0" >',
#  '#         <A>0.00000000e+000</A>',
#  '#         <B>0.00000000e+000</B>',
#  '#         <C>0.00000000e+000</C>',
#  '#         <D>0.00000000e+000</D>',
#  '#         <M>0.0</M>',
#  '#         <CPcor>-9.57000000e-008</CPcor>',
#  '#       </Coefficients>',
#  '#       <Coefficients equation="1" >',
#  '#         <G>-1.02888352e+001</G>',
#  '#         <H>1.37442397e+000</H>',
#  '#         <I>4.26946185e-004</I>',
#  '#         <J>4.88239855e-005</J>',
#  '#         <CPcor>-9.57000000e-008</CPcor>',
#  '#         <CTcor>3.2500e-006</CTcor>',
#  '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->',
#  '#         <WBOTC>0.00000000e+000</WBOTC>',
#  '#       </Coefficients>',
#  '#       <Slope>1.00000000</Slope>',
#  '#       <Offset>0.00000</Offset>',
#  '#     </ConductivitySensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="3" >',
#  '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->',
#  '#     <PressureSensor SensorID="45" >',
#  '#       <SerialNumber>0291</SerialNumber>',
#  '#       <CalibrationDate>31-Oct-17</CalibrationDate>',
#  '#       <C1>-3.801474e+004</C1>',
#  '#       <C2>3.649520e-001</C2>',
#  '#       <C3>1.289200e-002</C3>',
#  '#       <D1>3.847600e-002</D1>',
#  '#       <D2>0.000000e+000</D2>',
#  '#       <T1>3.029981e+001</T1>',
#  '#       <T2>-1.371950e-004</T2>',
#  '#       <T3>4.203520e-006</T3>',
#  '#       <T4>4.013720e-009</T4>',
#  '#       <Slope>0.99995000</Slope>',
#  '#       <Offset>-3.08750</Offset>',
#  '#       <T5>0.000000e+000</T5>',
#  '#       <AD590M>1.146000e-002</AD590M>',
#  '#       <AD590B>-8.308860e+000</AD590B>',
#  '#     </PressureSensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="4" >',
#  '#     <!-- Frequency 3, Temperature, 2 -->',
#  '#     <TemperatureSensor SensorID="55" >',
#  '#       <SerialNumber>2376</SerialNumber>',
#  '#       <CalibrationDate>14-Dec-17</CalibrationDate>',
#  '#       <UseG_J>1</UseG_J>',
#  '#       <A>0.00000000e+000</A>',
#  '#       <B>0.00000000e+000</B>',
#  '#       <C>0.00000000e+000</C>',
#  '#       <D>0.00000000e+000</D>',
#  '#       <F0_Old>0.000</F0_Old>',
#  '#       <G>4.37944570e-003</G>',
#  '#       <H>6.40434977e-004</H>',
#  '#       <I>2.22376120e-005</I>',
#  '#       <J>1.92090009e-006</J>',
#  '#       <F0>1000.000</F0>',
#  '#       <Slope>1.00000000</Slope>',
#  '#       <Offset>0.0000</Offset>',
#  '#     </TemperatureSensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="5" >',
#  '#     <!-- Frequency 4, Conductivity, 2 -->',
#  '#     <ConductivitySensor SensorID="3" >',
#  '#       <SerialNumber>043127</SerialNumber>',
#  '#       <CalibrationDate>01-Dec-17</CalibrationDate>',
#  '#       <UseG_J>1</UseG_J>',
#  '#       <!-- Cell const and series R are applicable only for wide range sensors. -->',
#  '#       <SeriesR>0.0000</SeriesR>',
#  '#       <CellConst>2000.0000</CellConst>',
#  '#       <ConductivityType>0</ConductivityType>',
#  '#       <Coefficients equation="0" >',
#  '#         <A>0.00000000e+000</A>',
#  '#         <B>0.00000000e+000</B>',
#  '#         <C>0.00000000e+000</C>',
#  '#         <D>0.00000000e+000</D>',
#  '#         <M>0.0</M>',
#  '#         <CPcor>-9.57000000e-008</CPcor>',
#  '#       </Coefficients>',
#  '#       <Coefficients equation="1" >',
#  '#         <G>-9.85850491e+000</G>',
#  '#         <H>1.21916926e+000</H>',
#  '#         <I>5.05069089e-005</I>',
#  '#         <J>5.60403381e-005</J>',
#  '#         <CPcor>-9.57000000e-008</CPcor>',
#  '#         <CTcor>3.2500e-006</CTcor>',
#  '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->',
#  '#         <WBOTC>0.00000000e+000</WBOTC>',
#  '#       </Coefficients>',
#  '#       <Slope>1.00000000</Slope>',
#  '#       <Offset>0.00000</Offset>',
#  '#     </ConductivitySensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="6" >',
#  '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->',
#  '#     <OxygenSensor SensorID="38" >',
#  '#       <SerialNumber>1961</SerialNumber>',
#  '#       <CalibrationDate>14-Dec-2017</CalibrationDate>',
#  '#       <Use2007Equation>1</Use2007Equation>',
#  '#       <CalibrationCoefficients equation="0" >',
#  '#         <!-- Coefficients for Owens-Millard equation. -->',
#  '#         <Boc>0.0000</Boc>',
#  '#         <Soc>0.0000e+000</Soc>',
#  '#         <offset>0.0000</offset>',
#  '#         <Pcor>0.00e+000</Pcor>',
#  '#         <Tcor>0.0000</Tcor>',
#  '#         <Tau>0.0</Tau>',
#  '#       </CalibrationCoefficients>',
#  '#       <CalibrationCoefficients equation="1" >',
#  '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->',
#  '#         <Soc>4.9600e-001</Soc>',
#  '#         <offset>-0.5238</offset>',
#  '#         <A>-2.8102e-003</A>',
#  '#         <B> 1.4692e-004</B>',
#  '#         <C>-1.7543e-006</C>',
#  '#         <D0> 2.5826e+000</D0>',
#  '#         <D1> 1.92634e-004</D1>',
#  '#         <D2>-4.64803e-002</D2>',
#  '#         <E> 3.6000e-002</E>',
#  '#         <Tau20> 1.1600</Tau20>',
#  '#         <H1>-3.3000e-002</H1>',
#  '#         <H2> 5.0000e+003</H2>',
#  '#         <H3> 1.4500e+003</H3>',
#  '#       </CalibrationCoefficients>',
#  '#     </OxygenSensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="7" >',
#  '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->',
#  '#     <OxygenSensor SensorID="38" >',
#  '#       <SerialNumber>0904</SerialNumber>',
#  '#       <CalibrationDate>15-DEC-17</CalibrationDate>',
#  '#       <Use2007Equation>1</Use2007Equation>',
#  '#       <CalibrationCoefficients equation="0" >',
#  '#         <!-- Coefficients for Owens-Millard equation. -->',
#  '#         <Boc>0.0000</Boc>',
#  '#         <Soc>0.0000e+000</Soc>',
#  '#         <offset>0.0000</offset>',
#  '#         <Pcor>0.00e+000</Pcor>',
#  '#         <Tcor>0.0000</Tcor>',
#  '#         <Tau>0.0</Tau>',
#  '#       </CalibrationCoefficients>',
#  '#       <CalibrationCoefficients equation="1" >',
#  '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->',
#  '#         <Soc>4.6610e-001</Soc>',
#  '#         <offset>-0.4778</offset>',
#  '#         <A>-3.9780e-003</A>',
#  '#         <B> 2.0665e-004</B>',
#  '#         <C>-2.8401e-006</C>',
#  '#         <D0> 2.5826e+000</D0>',
#  '#         <D1> 1.92634e-004</D1>',
#  '#         <D2>-4.64803e-002</D2>',
#  '#         <E> 3.6000e-002</E>',
#  '#         <Tau20> 1.1800</Tau20>',
#  '#         <H1>-3.3000e-002</H1>',
#  '#         <H2> 5.0000e+003</H2>',
#  '#         <H3> 1.4500e+003</H3>',
#  '#       </CalibrationCoefficients>',
#  '#     </OxygenSensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="8" >',
#  '#     <!-- A/D voltage 2, Turbidity Meter, WET Labs, ECO-NTU -->',
#  '#     <TurbidityMeter SensorID="67" >',
#  '#       <SerialNumber>2057</SerialNumber>',
#  '#       <CalibrationDate>8-Dec-2016</CalibrationDate>',
#  '#       <ScaleFactor>5.000000</ScaleFactor>',
#  '#       <!-- Dark output -->',
#  '#       <DarkVoltage>0.077000</DarkVoltage>',
#  '#     </TurbidityMeter>',
#  '#   </sensor>',
#  '#   <sensor Channel="9" >',
#  '#     <!-- A/D voltage 3, Fluorometer, WET Labs ECO-AFL/FL -->',
#  '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >',
#  '#       <SerialNumber>2057</SerialNumber>',
#  '#       <CalibrationDate>8-Dec-2016</CalibrationDate>',
#  '#       <ScaleFactor>1.00000000e+001</ScaleFactor>',
#  '#       <!-- Dark output -->',
#  '#       <Vblank>0.0730</Vblank>',
#  '#     </FluoroWetlabECO_AFL_FL_Sensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="10" >',
#  '#     <!-- A/D voltage 4, Altimeter -->',
#  '#     <AltimeterSensor SensorID="0" >',
#  '#       <SerialNumber>4708</SerialNumber>',
#  '#       <CalibrationDate>Dec 2016</CalibrationDate>',
#  '#       <ScaleFactor>15.000</ScaleFactor>',
#  '#       <Offset>-1.500</Offset>',
#  '#     </AltimeterSensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="11" >',
#  '#     <!-- A/D voltage 5, Free -->',
#  '#   </sensor>',
#  '#   <sensor Channel="12" >',
#  '#     <!-- A/D voltage 6, PAR/Irradiance, Biospherical/Licor -->',
#  '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >',
#  '#       <SerialNumber>70547</SerialNumber>',
#  '#       <CalibrationDate>30-JAN-18</CalibrationDate>',
#  '#       <M>1.00000000</M>',
#  '#       <B>0.00000000</B>',
#  '#       <CalibrationConstant>9620000000.00000000</CalibrationConstant>',
#  '#       <Multiplier>1.00000000</Multiplier>',
#  '#       <Offset>0.10500000</Offset>',
#  '#     </PAR_BiosphericalLicorChelseaSensor>',
#  '#   </sensor>',
#  '#   <sensor Channel="13" >',
#  '#     <!-- A/D voltage 7, Free -->',
#  '#   </sensor>',
#  '# </Sensors>',
#  '# datcnv_date = Sep 14 2018 17:48:53, 7.26.7.114 [datcnv_vars = 11]',
#  '# datcnv_in = c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.hex c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.XMLCON',
#  '# datcnv_skipover = 0',
#  '# datcnv_ox_hysteresis_correction = yes',
#  '# wildedit_date = Sep 14 2018 17:48:57, 7.26.7.114',
#  '# wildedit_in = c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.cnv',
#  '# wildedit_pass1_nstd = 2.0',
#  '# wildedit_pass2_nstd = 20.0',
#  '# wildedit_pass2_mindelta = 1.000e-002',
#  '# wildedit_npoint = 100',
#  '# wildedit_vars = c0mS/cm c1mS/cm flECO-AFL sbeox0V t090C t190C prDM sbeox1V par turbWETntu0',
#  '# wildedit_excl_bad_scans = yes',
#  '# alignctd_date = Sep 14 2018 17:48:58, 7.26.7.114',
#  '# alignctd_in = c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.cnv',
#  '# alignctd_adv = sbeox0V 3.000, sbeox1V 3.000',
#  '# celltm_date = Sep 14 2018 17:48:59, 7.26.7.114',
#  '# celltm_in = c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.cnv',
#  '# celltm_alpha = 0.0300, 0.0300',
#  '# celltm_tau = 7.0000, 7.0000',
#  '# celltm_temp_sensor_use_for_cond = primary, secondary',
#  '# filter_date = Sep 14 2018 17:49:15, 7.26.7.114',
#  '# filter_in = c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.cnv',
#  '# filter_low_pass_tc_A = 0.030',
#  '# filter_low_pass_tc_B = 0.150',
#  '# filter_low_pass_A_vars = flECO-AFL prDM sbeox1V par turbWETntu0',
#  '# filter_low_pass_B_vars =',
#  '# loopedit_date = Sep 14 2018 17:49:17, 7.26.7.114',
#  '# loopedit_in = c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.cnv',
#  '# loopedit_percentMeanSpeed: minV = 0.100, ws = 120, percent = 20.00',
#  '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0',
#  '# loopedit_excl_bad_scans = yes',
#  '# Derive_date = Sep 14 2018 17:49:19, 7.26.7.114 [derive_vars = 10]',
#  '# Derive_in = c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.cnv c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.XMLCON',
#  '# derive_time_window_docdt = seconds: 2',
#  '# derive_ox_tau_correction = yes',
#  '# binavg_date = Sep 14 2018 17:49:20, 7.26.7.114',
#  '# binavg_in = c:\\data\\ctd\\2018\\dy1805\\raw\\CTD\\ctd001.cnv',
#  '# binavg_bintype = decibars',
#  '# binavg_binsize = 1',
#  '# binavg_excl_bad_scans = yes',
#  '# binavg_skipover = 0',
#  '# binavg_omit = 0',
#  '# binavg_min_scans_bin = 1',
#  '# binavg_max_scans_bin = 2147483647',
#  '# binavg_surface_bin = yes, min = 0.000, max = 0.500, value = 0.000',
#  '# file_type = ascii']

# %%
ctd_df.header
# Out:
# ['* Sea-Bird SBE 9 Data File:',
#  '* FileName = C:\\Sea-Bird Data\\2018\\DY-18-05\\CTD\\CTD001.hex',
#  '* Software Version Seasave V 7.23.2',
#  '* Temperature SN = 4379',
#  '* Conductivity SN = 042985',
#  '* Number of Bytes Per Scan = 37',
#  '* Number of Voltage Words = 4',
#  '* Number of Scans Averaged by the Deck Unit = 1',
#  '* System UpLoad Time = Apr 30 2018 19:11:53',
#  '* NMEA Latitude = 56 52.31 N',
#  '* NMEA Longitude = 164 03.02 W',
#  '* NMEA UTC (Time) = Apr 30 2018  19:11:51',
#  '* Store Lat/Lon Data = Append to Every Scan',
#  '* SBE 11plus V 5.2',
#  '* number of scans to average = 1',
#  '* pressure baud rate = 9600',
#  '* NMEA baud rate = 4800',
#  '* Latitude/Longitude added to scan',
#  '* GPIB address = 1',
#  '* advance primary conductivity  0.073 seconds',
#  '* advance secondary conductivity  0.073 seconds',
#  '* autorun on power up is disabled',
#  '* S>',
#  '* System UTC = Apr 30 2018 19:11:53',
#  '*END*']

# %% [markdown]
# ## Using the file metadata, prefill out global/variable config data
#
# This will primarily be -
# + From header
#     - Sea-Bird system (line 0)
#     - original filename (line 1)
#     - Software Version (line 2)
#     - (lat, lon, time if from_cnv is True)
# + From config
#     - sensor serial number and cal-date -> variable meta
# + From Database of cast logs (even if piped to config file first)
#     - bottom_depth, max_depth
#     - lat, lon, time if from_database is True
# + From yaml_config (see test.yaml)
#     - variable names (long_name, standard_name, units)
#     - institution name
#     - contact information
#     - lat, lon, time if from_config is True (unlikely as this would be in database)
#     - title (ACDD 1.3)
#     - summary (ACDD 1.3)
#     - keywords
#     - conventions (ACDD 1.3, CF 1.7)
#     - history
#     - standard_name_vocabulary ()
#
# **To Think About**
# - is station name, castnumber, watermass - a variable or an attribute? (or both... maybe best)
# - flags? and flag_values

# %% [markdown]
# ## From Pandas to XArray
#
# use pandas variable names to identify variable meta information from config file

# %%
var_config= yaml.load(open('data/test_profile_variables.yaml'))

# %%
ctd_df.index.rename('depth', inplace=True) #units are dbar

for cname in ctd_df.columns:
    if cname in list(var_config.keys()):
        ctd_df.rename(columns = {cname:var_config[cname]['name']}, inplace = True)
        
drop_vars = ['nbin','flag']

# %%
ctd_xa = ctd_df.to_xarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-a07f3f3bd844> in <module>
# ----> 1 ctd_xa = ctd_df.to_xarray()
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/pandas/core/generic.py in to_xarray(self)
#    2740             return xarray.DataArray.from_series(self)
#    2741         elif self.ndim == 2:
# -> 2742             return xarray.Dataset.from_dataframe(self)
#    2743
#    2744         # > 2 dims
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/xarray/core/dataset.py in from_dataframe(cls, dataframe)
#    3106         if not dataframe.columns.is_unique:
#    3107             raise ValueError(
# -> 3108                 'cannot convert DataFrame with non-unique columns')
#    3109
#    3110         idx = dataframe.index
#
# ValueError: cannot convert DataFrame with non-unique columns

# %%
ctd_xa
#ctd_xa.to_netcdf(test_file+'.nc')
# Out:
# <xarray.Dataset>
# Dimensions:                                    (depth: 67)
# Coordinates:
#   * depth                                      (depth) float64 1.0 2.0 ... 67.0
# Data variables:
#     sea_water_electrical_conductivity_1        (depth) float64 29.75 ... 29.78
#     sea_water_electrical_conductivity_2        (depth) float64 29.76 ... 29.79
#     concentration_of_chlorophyll_in_sea_water  (depth) float64 0.4821 ... 0.8792
#     sbeox0V                                    (depth) float64 2.52 ... 2.525
#     sea_water_temperature_1                    (depth) float64 3.609 ... 3.61
#     sea_water_temperature_2                    (depth) float64 3.611 ... 3.61
#     timeS                                      (depth) float64 112.1 ... 543.7
#     sbeox1V                                    (depth) float64 2.594 ... 2.583
#     par                                        (depth) float64 304.0 ... 0.21
#     turbWETntu0                                (depth) float64 0.6675 ... 1.67
#     sea_water_salinity_1                       (depth) float64 32.07 ... 32.07
#     sea_water_salinity_2                       (depth) float64 32.07 ... 32.07
#     sigma-t00                                  (depth) float64 25.49 ... 25.49
#     sigma-t11                                  (depth) float64 25.49 ... 25.49
#     sbeox0ML/L                                 (depth) float64 7.326 ... 7.43
#     sbox0Mm/Kg                                 (depth) float64 319.0 ... 323.6
#     sbeox0PS                                   (depth) float64 98.19 ... 99.59
#     sbeox1ML/L                                 (depth) float64 7.283 ... 7.291
#     sbox1Mm/Kg                                 (depth) float64 317.2 ... 317.5
#     sbeox1PS                                   (depth) float64 97.63 ... 97.73
#     nbin                                       (depth) float64 15.0 ... 28.0
#     flag                                       (depth) bool False ... False
