# %%
# %matplotlib inline

# %% [markdown]
# Routines for mapping available at: https://ocefpaf.github.io/python4oceanographers/blog/2015/06/22/osm/

# %%
import matplotlib.pyplot as plt

import cartopy.crs as ccrs
from cartopy.io import shapereader
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER


def make_map(projection=ccrs.PlateCarree()):
    fig, ax = plt.subplots(figsize=(9, 13),
                           subplot_kw=dict(projection=projection))
    gl = ax.gridlines(draw_labels=True)
    gl.xlabels_top = gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    return fig, ax

extent = [-180, -135, 45, 80]

# %% [markdown]
# ***using Natural Earth***

# %%
from cartopy.feature import NaturalEarthFeature

coast = NaturalEarthFeature(category='physical', scale='10m',
                            facecolor='none', name='coastline')

fig, ax = make_map(projection=ccrs.PlateCarree())

#ax.set_extent(extent)

feature = ax.add_feature(coast, edgecolor='black')
# Out:
# /Volumes/WDC_internal/Users/bell/anaconda/lib/python2.7/site-packages/cartopy/io/__init__.py:264: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/10m/physical/ne_10m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %% [markdown]
# ***using basic coastline command***

# %%
fig,ax = make_map(projection=ccrs.PlateCarree())

ax.coastlines(resolution='50m')
# Out:
# /Volumes/WDC_internal/Users/bell/anaconda/lib/python2.7/site-packages/cartopy/io/__init__.py:264: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/50m/physical/ne_50m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %% [markdown]
# ***using OSM Generalized coastline maps***
#
# http://openstreetmapdata.com/data/generalized-coastlines

# %%
import cartopy.feature as cfeature

fig, ax = make_map(projection=ccrs.PlateCarree())
ax.set_extent(extent)

shp = cfeature.shapereader.Reader('data/simple_coastlines/Alaska.shp')
for record, geometry in zip(shp.records(), shp.geometries()):
    ax.add_geometries([geometry], ccrs.PlateCarree(), facecolor='lightgray',
                      edgecolor='black')
# Out:
# ---------------------------------------------------------------------------
# ShapefileException                        Traceback (most recent call last)
# <ipython-input-8-0b72fc6f4cd6> in <module>()
#       4 ax.set_extent(extent)
#       5
# ----> 6 shp = cfeature.shapereader.Reader('data/simple_coastlines/Alaska.shp')
#       7 for record, geometry in zip(shp.records(), shp.geometries()):
#       8     ax.add_geometries([geometry], ccrs.PlateCarree(), facecolor='lightgray',
#
# /Volumes/WDC_internal/Users/bell/anaconda/lib/python2.7/site-packages/cartopy/io/shapereader.pyc in __init__(self, filename)
#     185     def __init__(self, filename):
#     186         # Validate the filename/shapefile
# --> 187         self._reader = reader = shapefile.Reader(filename)
#     188         if reader.shp is None or reader.shx is None or reader.dbf is None:
#     189             raise ValueError("Incomplete shapefile definition "
#
# /Volumes/WDC_internal/Users/bell/anaconda/lib/python2.7/site-packages/shapefile.pyc in __init__(self, *args, **kwargs)
#     232         if len(args) > 0:
#     233             if is_string(args[0]):
# --> 234                 self.load(args[0])
#     235                 return
#     236         if "shp" in kwargs.keys():
#
# /Volumes/WDC_internal/Users/bell/anaconda/lib/python2.7/site-packages/shapefile.pyc in load(self, shapefile)
#     265                 self.shp = open("%s.shp" % shapeName, "rb")
#     266             except IOError:
# --> 267                 raise ShapefileException("Unable to open %s.shp" % shapeName)
#     268             try:
#     269                 self.shx = open("%s.shx" % shapeName, "rb")
#
# ShapefileException: Unable to open data/simple_coastlines/Alaska.shp

# %% [markdown]
# The previous routine doesn't plot the shapefile as would be expected.  The shapefile itself is valid and tested in QGIS so the questions is "what is preventing the succesful plot of a map".

# %%
fig, ax = make_map(projection=ccrs.PlateCarree())
ax.set_extent(extent)

shp = cfeature.shapereader.Reader('data/coastlines/Alaska.shp')
for record, geometry in zip(shp.records(), shp.geometries()):
    ax.add_geometries([geometry], ccrs.PlateCarree(), facecolor='lightgray',
                      edgecolor='black')

# %% [markdown]
# ***using OSM (trimmed) coastline maps***
#
# http://openstreetmapdata.com/data/coastlines

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent(extent)

shp = cfeature.shapereader.Reader('data/coastlines/Alaska.shp')
for record, geometry in zip(shp.records(), shp.geometries()):
    ax.add_geometries([geometry], ccrs.PlateCarree(), facecolor='white',
                      edgecolor='black')
